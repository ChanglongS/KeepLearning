# %%
import numpy as np

# %%
us_data = np.loadtxt('./day54/youtube_video_data/US_video_data_numbers.csv', delimiter=",", usecols=(1, 2))
print(us_data.shape)
# Out:
# (1688, 2)

# %%
us_data_comments = us_data[:, 0]
us_data_likes = us_data[:,1]
print(us_data_comments.shape)
print(us_data_likes.shape)
# Out:
# (1688,)
# (1688,)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(us_data_comments, us_data_likes)
